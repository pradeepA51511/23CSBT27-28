# %% [markdown]
# <a href="https://colab.research.google.com/github/pradeepA51511/23CSBT27-28/blob/main/DFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DFS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
graph1 = {
 'A' : ['B','C','G'],
 'B' : ['A'],
 'C' : ['A','D','F',],
 'D' : ['A','C','E','H'],
 'E' : ['D','H','F'],
 'F' : ['C','E'],
 'G' : ['A','D','H'],
 'H' : ['D','E','G']
}
def dfs(graph, node, visited):
  if node not in visited:
     visited.append(node)
     for k in graph[node]:
       dfs(graph,k, visited)
  return visited
visited = dfs(graph1,'B', [])
print(visited)
# Out:
# ['B', 'A', 'C', 'D', 'E', 'H', 'G', 'F']
